# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'../Data/DailyFailureWeather_5_15.csv')

# %%
NWD=df.Temp

# %%
hist = plt.hist(NWD, bins=30, density=True)

# %%
Temp =df.groupby(['Temp'])['Failure.Rate'].agg('sum')

# %%
FWD = []
for T in Temp.index :
    FWD.extend([T] *int(Temp[T]))
FWD = np.asarray(FWD)

# %%
hist = plt.hist(FWD, bins=30, density=True)

# %%
x_d = np.linspace(15, 42, 2000)

# %%
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
Nkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Nkde.fit(NWD[:, None])
# score_samples returns the log of the probability density
Nlogprob = Nkde.score_samples(x_d[:, None])

Fkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Fkde.fit(FWD[:, None])
# score_samples returns the log of the probability density
Flogprob = Fkde.score_samples(x_d[:, None])

plt.fill_between(x_d, np.exp(Nlogprob), alpha=0.5,label='Normal Temp')
plt.fill_between(x_d, np.exp(Flogprob), alpha=0.5,label='Failure Temp')
plt.legend(loc='upper left')

#plt.plot(NWD, np.full_like(NWD, -0.01), '|k', markeredgewidth=1)
plt.ylim(0, 0.1)
# Out:
# /tmp/ipykernel_20418/783069300.py:5: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Nkde.fit(NWD[:, None])
# (0.0, 0.1)

# %%
np.sum(np.abs((np.exp(Nlogprob)-np.exp(Flogprob))))*(x_d[1]-x_d[0])
# Out:
# 0.5829999193184902

# %%
##############
### 5 days ###
##############
NWD=df.Temp5.dropna()
Temp =df.groupby(['Temp5'])['Failure.Rate'].agg('sum')
FWD = []
for T in Temp.index :
    FWD.extend([T] *int(Temp[T]))
FWD = np.asarray(FWD)
x_d = np.linspace(15, 42, 2000)
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
Nkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Nkde.fit(NWD[:, None])
# score_samples returns the log of the probability density
Nlogprob = Nkde.score_samples(x_d[:, None])

Fkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Fkde.fit(FWD[:, None])
# score_samples returns the log of the probability density
Flogprob = Fkde.score_samples(x_d[:, None])

plt.fill_between(x_d, np.exp(Nlogprob), alpha=0.5,label='Normal Temp5')
plt.fill_between(x_d, np.exp(Flogprob), alpha=0.5,label='Failure Temp5')
plt.legend(loc='upper left')

#plt.plot(NWD, np.full_like(NWD, -0.01), '|k', markeredgewidth=1)
plt.ylim(0, 0.1)
np.sum(np.abs((np.exp(Nlogprob)-np.exp(Flogprob))))*(x_d[1]-x_d[0])
# Out:
# /tmp/ipykernel_20418/3513476130.py:15: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Nkde.fit(NWD[:, None])
# 1.1589175108699465

# %%
##############
### 10 days ###
##############
NWD=df.Temp10.dropna()
Temp =df.groupby(['Temp10'])['Failure.Rate'].agg('sum')
FWD = []
for T in Temp.index :
    FWD.extend([T] *int(Temp[T]))
FWD = np.asarray(FWD)
x_d = np.linspace(15, 42, 2000)
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
Nkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Nkde.fit(NWD[:, None])
# score_samples returns the log of the probability density
Nlogprob = Nkde.score_samples(x_d[:, None])

Fkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Fkde.fit(FWD[:, None])
# score_samples returns the log of the probability density
Flogprob = Fkde.score_samples(x_d[:, None])

plt.fill_between(x_d, np.exp(Nlogprob), alpha=0.5,label='Normal Temp')
plt.fill_between(x_d, np.exp(Flogprob), alpha=0.5,label='Failure Temp')
plt.legend(loc='upper left')

#plt.plot(NWD, np.full_like(NWD, -0.01), '|k', markeredgewidth=1)
plt.ylim(0, 0.12)
plt.xlabel('Avg. 10 days temperature ')
np.sum(np.abs((np.exp(Nlogprob)-np.exp(Flogprob))))*(x_d[1]-x_d[0])
# Out:
# /tmp/ipykernel_20418/2731956198.py:15: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Nkde.fit(NWD[:, None])
# 1.285920031657789

# %%
##############
### 15 days ###
##############
NWD=df.Temp15.dropna()
Temp =df.groupby(['Temp15'])['Failure.Rate'].agg('sum')
FWD = []
for T in Temp.index :
    FWD.extend([T] *int(Temp[T]))
FWD = np.asarray(FWD)
x_d = np.linspace(15, 42, 2000)
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
Nkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Nkde.fit(NWD[:, None])
# score_samples returns the log of the probability density
Nlogprob = Nkde.score_samples(x_d[:, None])

Fkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Fkde.fit(FWD[:, None])
# score_samples returns the log of the probability density
Flogprob = Fkde.score_samples(x_d[:, None])

plt.fill_between(x_d, np.exp(Nlogprob), alpha=0.5,label='Normal Temp')
plt.fill_between(x_d, np.exp(Flogprob), alpha=0.5,label='Failure Temp')
plt.legend(loc='upper left')

#plt.plot(NWD, np.full_like(NWD, -0.01), '|k', markeredgewidth=1)
plt.ylim(0, 0.12)
np.sum(np.abs((np.exp(Nlogprob)-np.exp(Flogprob))))*(x_d[1]-x_d[0])
# Out:
# /tmp/ipykernel_20418/2343812101.py:15: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Nkde.fit(NWD[:, None])
# 1.329844922722528

# %%
##############
### 7 days ###
##############
NWD=df.Temp7.dropna()
Temp =df.groupby(['Temp7'])['Failure.Rate'].agg('sum')
FWD = []
for T in Temp.index :
    FWD.extend([T] *int(Temp[T]))
FWD = np.asarray(FWD)
x_d = np.linspace(15, 42, 2000)
from sklearn.neighbors import KernelDensity

# instantiate and fit the KDE model
Nkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Nkde.fit(NWD[:, None])
# score_samples returns the log of the probability density
Nlogprob = Nkde.score_samples(x_d[:, None])

Fkde = KernelDensity(bandwidth=1.0, kernel='gaussian')
Fkde.fit(FWD[:, None])
# score_samples returns the log of the probability density
Flogprob = Fkde.score_samples(x_d[:, None])

plt.fill_between(x_d, np.exp(Nlogprob), alpha=0.5,label='Normal Temp')
plt.fill_between(x_d, np.exp(Flogprob), alpha=0.5,label='Failure Temp')
plt.legend(loc='upper left')

#plt.plot(NWD, np.full_like(NWD, -0.01), '|k', markeredgewidth=1)
plt.ylim(0, 0.12)
np.sum(np.abs((np.exp(Nlogprob)-np.exp(Flogprob))))*(x_d[1]-x_d[0])
# Out:
# /tmp/ipykernel_20418/1206942508.py:15: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   Nkde.fit(NWD[:, None])
# 1.3175344830966533
